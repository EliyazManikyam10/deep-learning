# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np

# %%
turbine=pd.read_csv("gas_turbines.csv")

# %%
turbine
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# ...

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
scale=MinMaxScaler()
turbine1=pd.DataFrame(scale.fit_transform(turbine),columns=['AT','AP','AH','AFDP','GTEP','TIT','TAT','TEY','CDP','CO','NOX'])

# %%
turbine1
# Out:
#              AT        AP        AH      AFDP      GTEP    TIT       TAT  \
# 0      0.184182  0.456050  0.951314  0.255758  0.091426  0.584  0.984015
# 1      0.182020  0.466391  0.955881  0.255721  0.094755  0.585  0.984015
# 2      0.185295  0.474664  0.939003  0.252571  0.097367  0.586  0.980608
# 3      0.189922  0.482937  0.929126  0.252227  0.098033  0.588  0.983753
# 4      0.199830  0.493278  0.927708  0.255323  0.096650  0.589  0.983491
# ...         ...       ...       ...       ...       ...    ...       ...
# 15034  0.247272  0.408480  0.975092  0.263380  0.065868  0.489  0.884696
# 15035  0.214075  0.414685  0.984153  0.256826  0.078672  0.455  0.806342
# 15036  0.195962  0.422958  0.989922  0.251593  0.084614  0.369  0.651730
# 15037  0.188443  0.433299  0.982936  0.246451  0.076777  0.424  0.754455
# 15038  0.186173  0.441572  0.961821  0.242631  0.073141  0.491  0.875262
#
#             TEY       CDP        CO       NOX
# ...

# %%
sc=StandardScaler()
turbine2=pd.DataFrame(sc.fit_transform(turbine),columns=['AT','AP','AH','AFDP','GTEP','TIT','TAT','TEY','CDP','CO','NOX'])

# %%
turbine2
# Out:
#              AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# 0     -1.439778 -0.826644  1.281436 -0.921232 -1.379101 -1.488376  0.585240
# 1     -1.449601 -0.748647  1.304564 -0.921495 -1.363528 -1.482325  0.585240
# 2     -1.434721 -0.686250  1.219086 -0.944385 -1.351309 -1.476275  0.568715
# 3     -1.413702 -0.623853  1.169060 -0.946884 -1.348194 -1.464173  0.583969
# 4     -1.368693 -0.545857  1.161883 -0.924389 -1.354663 -1.458123  0.582698
# ...         ...       ...       ...       ...       ...       ...       ...
# 15034 -1.153182 -1.185428  1.401860 -0.865850 -1.498657 -2.063184  0.103453
# 15035 -1.303986 -1.138630  1.447753 -0.913470 -1.438759 -2.268905 -0.276638
# 15036 -1.386267 -1.076233  1.476971 -0.951488 -1.410967 -2.789257 -1.026650
# 15037 -1.420423 -0.998236  1.441590 -0.988848 -1.447624 -2.456474 -0.528337
# 15038 -1.430734 -0.935839  1.334652 -1.016605 -1.464635 -2.051083  0.057689
#
#             TEY       CDP        CO       NOX
# ...

# %%
x=turbine2.drop('TEY',axis=1).values
y=turbine2.TEY.values

seed=7
np.random.seed(seed)

# %%
turbine.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# ...

# %%
turbine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
#turbine1.isna().sum()

# %%
#turbine1.duplicated().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots(4, 3, figsize=(20,10))

sns.distplot(turbine2.AT,ax=ax[0,0])
sns.distplot(turbine2.AP,ax=ax[0,1])
sns.distplot(turbine2.AH,ax=ax[0,2])
sns.distplot(turbine2.AFDP,ax=ax[1,0])
sns.distplot(turbine2.GTEP,ax=ax[1,1])
sns.distplot(turbine2.TIT,ax=ax[1,2])
sns.distplot(turbine2.TAT,ax=ax[2,0])
sns.distplot(turbine2.TEY,ax=ax[2,1])
sns.distplot(turbine2.CDP,ax=ax[2,2])
sns.distplot(turbine2.CO,ax=ax[3,0])
sns.distplot(turbine2.NOX,ax=ax[3,1])
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='Density'>

# %%
fig,ax=plt.subplots(4, 3, figsize=(20,10))

sns.distplot(turbine.AT,ax=ax[0,0])
sns.distplot(turbine.AP,ax=ax[0,1])
sns.distplot(turbine.AH,ax=ax[0,2])
sns.distplot(turbine.AFDP,ax=ax[1,0])
sns.distplot(turbine.GTEP,ax=ax[1,1])
sns.distplot(turbine.TIT,ax=ax[1,2])
sns.distplot(turbine.TAT,ax=ax[2,0])
sns.distplot(turbine.TEY,ax=ax[2,1])
sns.distplot(turbine.CDP,ax=ax[2,2])
sns.distplot(turbine.CO,ax=ax[3,0])
sns.distplot(turbine.NOX,ax=ax[3,1])
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='Density'>

# %%
fig,ax=plt.subplots(4, 3, figsize=(20,10))

sns.distplot(turbine1.AT,ax=ax[0,0])
sns.distplot(turbine1.AP,ax=ax[0,1])
sns.distplot(turbine1.AH,ax=ax[0,2])
sns.distplot(turbine1.AFDP,ax=ax[1,0])
sns.distplot(turbine1.GTEP,ax=ax[1,1])
sns.distplot(turbine1.TIT,ax=ax[1,2])
sns.distplot(turbine1.TAT,ax=ax[2,0])
sns.distplot(turbine1.TEY,ax=ax[2,1])
sns.distplot(turbine1.CDP,ax=ax[2,2])
sns.distplot(turbine1.CO,ax=ax[3,0])
sns.distplot(turbine1.NOX,ax=ax[3,1])

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from keras.layers import Dense

# %%
# model

model1=Sequential()
model1.add(Dense(12,input_dim=10,kernel_initializer='uniform',activation='relu'))
model1.add(Dense(8,kernel_initializer='uniform',activation='relu'))
model1.add(Dense(1,kernel_initializer='uniform',activation='linear'))

# %%
model1.compile(loss='MSE',optimizer='adam',metrics=['accuracy'])

# %%
history = model1.fit(x,y,validation_split=0.33, epochs=100, batch_size=60)
# Out:
# Epoch 1/100
# Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x1470dd670>
# Traceback (most recent call last):
#   File "/Users/lakshmipriya/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py", line 545, in __del__
#     gen_dataset_ops.delete_iterator(
#   File "/Users/lakshmipriya/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1263, in delete_iterator
#     _result = pywrap_tfe.TFE_Py_FastPathExecute(
# KeyboardInterrupt:
# 168/168 [==============================] - 31s 2ms/step - loss: 0.5635 - accuracy: 0.0000e+00 - val_loss: 0.0390 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 168/168 [==============================] - 0s 1ms/step - loss: 0.0237 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 168/168 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 4/100
# ...

# %%
model1.history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.wrappers.scikit_learn import KerasClassifier

# %%
from tensorflow.keras.optimizers import Adam

# %%
def model2():
    
    model = Sequential()
    model.add(Dense(12, input_dim=10, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    
    
    adam=Adam(lr=0.01)
    model.compile(loss='mse', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = model2,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(x,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............ batch_size=10, epochs=10, score=0.000, total=   7.8s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.8s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.000, total=   8.0s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   15.8s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.000, total=  11.0s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   26.8s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.000, total=   9.4s
# ...

# %%
grid_result.best_params_
grid_result.best_score_
